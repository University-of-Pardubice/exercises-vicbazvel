# %% [markdown]
# # Nine, simplified fifteen
# ![image.png](attachment:image.png)
#
# Initial and final state
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Task
# 1. Create a State class that can preserve the state of the puzzle. The class will have implemented:
#     * constructor
#     * an equal method
#     * the expand method
#
# 2. Execute the expand method and check the result
#
# You need to complete the code in the places marked with # !!! todo

# %%
import copy

# %%
class State:
    """ Capturing the state 
    
    gameplan - two-dimensional array
             - values 1 - 8 stones
             - value 0 is a space
    row      - row position of the space
    column   - column position of the space
    """
    
    generated = 0
    
    def __init__(self, gameplan, row, column):
        # !!! todo
        pass
                
    def expand(self, action):
        # !!! todo
        pass

    def __eq__(self, other):
        # !!! todo
        pass

# %% [markdown]
# # Tests
# The following tests must pass without error.

# %%
actions=['l', 'r', 'u', 'd']

# %%
initial_state = State([[7,2,4],[5,0,6],[8,3,1]], 1, 1)

# %%
# Action check left
state_left = initial_state.expand('l')
assert (state_left.gameplan == [[7,2,4],[0,5,6],[8,3,1]])
print (state_left.gameplan)

# %%
# Action check right
state_right = initial_state.expand('r')
assert (state_right.gameplan == [[7,2,4],[5,6,0],[8,3,1]])
print (state_right.gameplan)

# %%
# Action check up
state_up = initial_state.expand('u')
assert (state_up.gameplan == [[7,0,4],[5,2,6],[8,3,1]])
print (state_up.gameplan)

# %%
# Action check down
state_down = initial_state.expand('d')
assert (state_down.gameplan == [[7,2,4],[5,3,6],[8,0,1]])
print (state_down.gameplan)
