# %% [markdown]
# # Wolf, goat and cabbage
# The ferryman has to transport a goat, a wolf and cabbage in a boat. The boat is small, so it can hold only one animal, or a cartload of cabbage.
#
# So he can carry either only the goat, or only the wolf, or only the cabbage. He can also ride in the boat alone.
#
# He must not leave the wolf and the goat unattended on one bank (the wolf would eat the goat) or the goat and the cabbage (the goat would eat the cabbage).
#
# He can safely leave the wolf and the cabbage on the bank, because the wolf does not like cabbage.

# %% [markdown]
# We can represent the state space.
#
# ![mfx0J.png](attachment:mfx0J.png)

# %% [markdown]
# # Task
# 1. Summarize how to record the state of a puzzle
# 2. Suggest actions
# 3. Create a State class that can record the state of a logical task and implements the equal and expand methods. If the action should produce an illegal state, return None
# 4. Test the class on different actions

# %% [markdown]
# # Hint
# You can use two sets to capture the state
#
# - To check if an element is in a set, use the **in** operator
# - To add an element to a set, there is the **add** method
# - To remove an element from the set, there is the **discard** method

# %%
import copy

# %%
class State:
    """ 
    
    """

    generated = 0
    
    def __init__(self, left, right):                               
        # todo
        pass
        
    def expand(self, action):
        # todo
        pass               
        

    def __eq__(self, other):  
        # todo       
        pass

# %% [markdown]
# # Testing
# Try out different allowed and disallowed actions. Tests must not end with an exception, otherwise you have a class that is not implemented correctly.

# %%
initial_state = State ({'P', 'K', 'Z', 'V'}, set())
new_state = initial_state.expand('PK')
assert (new_state.left == {'Z','V'} )
assert (new_state.right == {'P','K'} )
print (new_state.left, new_state.right)

# %%
initial_state = State ({'Z', 'V'}, {'P', 'K'})
new_state = initial_state.expand('P')
assert (new_state.left == {'P','Z','V'} )
assert (new_state.right == {'K'} )
print (new_state.left, new_state.right)

# %%
# unpossible action
initial_state = State ({'Z', 'V'}, {'P', 'K'})
new_state = initial_state.expand('K')
assert (new_state is None )

# %%
# unauthorised action
initial_state = State ({'P', 'K', 'Z', 'V'}, set())
new_state = initial_state.expand('P')
assert (new_state is None )
